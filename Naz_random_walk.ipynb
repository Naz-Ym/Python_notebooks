# %% [markdown]
# 1, 2. Set value of “destination” (thus establishing the length of the path)
# Initialize the value of “location” to 1 (the first step on the path)
# While “location” < “destination”
# Generate a random value “move”
# If the “move” is a positive value (so, half of the time, go forward)
#  increment “location”
# Else decrement “location”
# Also, do you see a potential problem in the pseudocode?
# Hint – examine the last line. Here it can become negative move?? Doesn't it mean that he is moving backwards as simple as that.

# %%
import random
destination = 10
location = 1
while location < destination:
    move = random.uniform(-1, 1)
    if move > 0:
        location += 1
    else:
        location -= 1

# %%
import random
destination = 10
location = 1
totalsteps = 1
while location < destination:
    move = random.uniform(-1, 1)
    totalsteps += 1
    if move > 0:
        location += 1
    else:
        location -= 1

# %% [markdown]
# 3.
# Now, notice something simple. If you run the code, at the end, you only know two things: that
# “Location” = “Destination” (because the program finished), and also the total number of steps taken.
# But there is no indication of the status of the walk, in terms of what is the current location at any
# given moment of the simulation.
# So, there is a need to show the status during runtime … a single line could do so, by displaying the
# value of “location” each time a move is generated, and perhaps the value of “totalsteps”.

# %%
import random
destination = 10
location = 1
totalsteps = 1
while location < destination:
    move = random.uniform(-1, 1)
    totalsteps += 1
    if move > 0:
        location += 1
    else:
        location -= 1
    print("The location of my person is {}, {})".format(location, totalsteps))
# Out:
# The location of my person is 2, 2)
# The location of my person is 1, 3)
# The location of my person is 0, 4)
# The location of my person is -1, 5)
# The location of my person is -2, 6)
# The location of my person is -1, 7)
# The location of my person is -2, 8)
# The location of my person is -3, 9)
# The location of my person is -2, 10)
# The location of my person is -3, 11)
# The location of my person is -4, 12)
# The location of my person is -3, 13)
# The location of my person is -2, 14)
# The location of my person is -1, 15)
# The location of my person is -2, 16)
# The location of my person is -3, 17)
# The location of my person is -2, 18)
# The location of my person is -3, 19)
# The location of my person is -2, 20)
# The location of my person is -1, 21)
# The location of my person is 0, 22)
# The location of my person is 1, 23)
# The location of my person is 2, 24)
# The location of my person is 3, 25)
# The location of my person is 4, 26)
# The location of my person is 3, 27)
# The location of my person is 2, 28)
# The location of my person is 1, 29)
# The location of my person is 2, 30)
# The location of my person is 3, 31)
# The location of my person is 2, 32)
# The location of my person is 3, 33)
# The location of my person is 4, 34)
# The location of my person is 5, 35)
# The location of my person is 4, 36)
# The location of my person is 5, 37)
# The location of my person is 6, 38)
# The location of my person is 7, 39)
# The location of my person is 8, 40)
# The location of my person is 7, 41)
# The location of my person is 6, 42)
# The location of my person is 5, 43)
# The location of my person is 6, 44)
# The location of my person is 7, 45)
# The location of my person is 6, 46)
# The location of my person is 5, 47)
# The location of my person is 6, 48)
# The location of my person is 7, 49)
# The location of my person is 6, 50)
# The location of my person is 7, 51)
# The location of my person is 8, 52)
# The location of my person is 9, 53)
# The location of my person is 10, 54)

# %%
import random
destination = 20
location = 1
totalsteps = 1
while location < destination:
    move = random.uniform(-1, 1)
    totalsteps += 1
    if move > 0:
        location += 1
    else:
        location -= 1
    #print("The location of my person is {}, {})".format(location, totalsteps))

# %%
import random
destination = 40
location = 1
totalsteps = 1
while location < destination:
    move = random.uniform(-1, 1)
    totalsteps += 1
    if move > 0:
        location += 1
    else:
        location -= 1
    #print("The location of my person is {}, {})".format(location, totalsteps))

# %% [markdown]
# 4.
# Now, notice something interesting. If the path is long, with an equal probability of moving either
# forwards or backwards, the walk could continue for quite a long time (why?). Experiment by running
# the simulation multiple times, across longer and longer path lengths, and retaining the values of
# totalsteps. How much variation is there?
# Experiment further by introducing a slight bias in the forward direction… an easy way to do this is to
# generate a random number between 1 and 100, and, say, go forward for any value 1-51, then 1-52,
# and so on, and monitor what happens to the values of totalsteps as you do so.

# %%
import random
destination = 10
location = 1
totalsteps = 1
while location < destination:
    move = random.uniform(1, 100)
    totalsteps += 1
    if move < 52:
        location += 1
    else:
        location -= 1
    print("The location of my person is {}, {})".format(location, totalsteps))
# Out:
# The location of my person is 2, 2)
# The location of my person is 3, 3)
# The location of my person is 4, 4)
# The location of my person is 5, 5)
# The location of my person is 4, 6)
# The location of my person is 3, 7)
# The location of my person is 4, 8)
# The location of my person is 3, 9)
# The location of my person is 2, 10)
# The location of my person is 1, 11)
# The location of my person is 2, 12)
# The location of my person is 3, 13)
# The location of my person is 2, 14)
# The location of my person is 1, 15)
# The location of my person is 0, 16)
# The location of my person is 1, 17)
# The location of my person is 2, 18)
# The location of my person is 1, 19)
# The location of my person is 2, 20)
# The location of my person is 3, 21)
# The location of my person is 2, 22)
# The location of my person is 3, 23)
# The location of my person is 2, 24)
# The location of my person is 1, 25)
# The location of my person is 2, 26)
# The location of my person is 1, 27)
# The location of my person is 2, 28)
# The location of my person is 3, 29)
# The location of my person is 2, 30)
# The location of my person is 3, 31)
# The location of my person is 2, 32)
# The location of my person is 1, 33)
# The location of my person is 0, 34)
# The location of my person is 1, 35)
# The location of my person is 2, 36)
# The location of my person is 1, 37)
# The location of my person is 0, 38)
# The location of my person is 1, 39)
# The location of my person is 0, 40)
# The location of my person is 1, 41)
# The location of my person is 0, 42)
# The location of my person is -1, 43)
# The location of my person is -2, 44)
# The location of my person is -3, 45)
# The location of my person is -2, 46)
# The location of my person is -1, 47)
# The location of my person is 0, 48)
# The location of my person is -1, 49)
# The location of my person is 0, 50)
# The location of my person is -1, 51)
# The location of my person is 0, 52)
# The location of my person is -1, 53)
# The location of my person is 0, 54)
# The location of my person is -1, 55)
# The location of my person is 0, 56)
# The location of my person is 1, 57)
# The location of my person is 0, 58)
# The location of my person is -1, 59)
# The location of my person is 0, 60)
# The location of my person is 1, 61)
# The location of my person is 2, 62)
# The location of my person is 1, 63)
# The location of my person is 2, 64)
# The location of my person is 1, 65)
# The location of my person is 0, 66)
# The location of my person is 1, 67)
# The location of my person is 2, 68)
# The location of my person is 1, 69)
# The location of my person is 2, 70)
# The location of my person is 3, 71)
# The location of my person is 2, 72)
# The location of my person is 3, 73)
# The location of my person is 2, 74)
# The location of my person is 3, 75)
# The location of my person is 4, 76)
# The location of my person is 3, 77)
# The location of my person is 4, 78)
# The location of my person is 3, 79)
# The location of my person is 4, 80)
# The location of my person is 5, 81)
# The location of my person is 4, 82)
# The location of my person is 3, 83)
# The location of my person is 2, 84)
# The location of my person is 1, 85)
# The location of my person is 0, 86)
# The location of my person is 1, 87)
# The location of my person is 2, 88)
# The location of my person is 3, 89)
# The location of my person is 2, 90)
# The location of my person is 3, 91)
# The location of my person is 4, 92)
# The location of my person is 3, 93)
# The location of my person is 2, 94)
# The location of my person is 3, 95)
# The location of my person is 4, 96)
# The location of my person is 5, 97)
# The location of my person is 6, 98)
# The location of my person is 5, 99)
# The location of my person is 4, 100)
# The location of my person is 3, 101)
# The location of my person is 4, 102)
# The location of my person is 5, 103)
# The location of my person is 6, 104)
# The location of my person is 7, 105)
# The location of my person is 8, 106)
# The location of my person is 7, 107)
# The location of my person is 8, 108)
# The location of my person is 9, 109)
# The location of my person is 10, 110)

# %%
import random
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
dic1 = dict()
dic2 = dict()
n_average = 100
for destination in range(10, 50, 2):
    tstep_list = []
    for i in range(n_average):
        location = 1
        totalsteps = 1
        while location < destination:
            move = random.uniform(1, 100)
            totalsteps += 1
            if move < 52:
                location += 1
            else:
                location -= 1
        tstep_list.append(totalsteps)
    dic1[destination] = np.mean(tstep_list)
    dic2[destination] = np.std(tstep_list)
print(dic1)
print(dic2)
x= list(dic1.keys())
y = list(dic1.values())
plt.plot(x, y)
plt.show()
x= list(dic2.keys())
y = list(dic2.values())
plt.plot(x, y)
plt.show()
# Out:
# {10: 342.68, 12: 406.44, 14: 370.8, 16: 582.12, 18: 389.92, 20: 579.34, 22: 758.58, 24: 817.02, 26: 774.76, 28: 757.26, 30: 878.86, 32: 901.18, 34: 1147.34, 36: 867.3, 38: 1271.92, 40: 1291.12, 42: 1347.14, 44: 1335.18, 46: 1381.46, 48: 1611.74}
# {10: 728.6384683778367, 12: 1053.216277124504, 14: 446.1222254046529, 16: 907.3678336815781, 18: 429.03071405203616, 20: 706.2238769682034, 22: 843.6627902189359, 24: 956.8272778302257, 26: 684.204693348416, 28: 775.8624442515567, 30: 807.4021181542689, 32: 1013.0623315472745, 34: 1123.2183778767153, 36: 629.0874263566234, 38: 1250.801564437781, 40: 1102.5308093654344, 42: 1513.8913106296634, 44: 945.1115106695082, 46: 1425.1696560059088, 48: 1326.8360156402148}

# %%
import random
import matplotlib.pyplot as plt
# %matplotlib inline
dic1 = dict()
n_average = 100
for bias in range(52, 70, 2):
    average = []
#     print(bias)
    for i in range(n_average):
#         print(i, end=" ")
        location = 1
        totalsteps = 1
        destination = 10
        while location < destination:
            move = random.uniform(1, 100)
            totalsteps += 1
            if move < bias:
                location += 1
            else:
                location -= 1
        average.append(totalsteps)
    dic1[bias] = np.mean(average)
print(dic1)
x= list(dic1.keys())
y = list(dic1.values())
plt.plot(x, y)
plt.show()
# Out:
# {52: 369.9, 54: 127.28, 56: 78.68, 58: 53.7, 60: 51.9, 62: 39.64, 64: 31.84, 66: 30.92, 68: 27.02}

# %% [markdown]
# 5.
# However, we still have not retained the information regarding how many times each stone was
# visited (touched, stepped on, etc.). Doing so involves the introduction of a counter for each stone in
# the path, or, in programming terms, an array of integer variables called “path”, such that
# “path[location]” would hold the number of times that element of the path had been visited.

# %%
import random
destination = 10
location = 1
totalsteps = 1
dic1 = dict()
while location < destination:
    move = random.uniform(1, 100)
    totalsteps += 1
    if move < 52:
        location += 1
    else:
        location -= 1
    if location not in dic1:
        dic1[location] = 1
    else:
        dic1[location] += 1       
    print("The location of my person is {}, and total steps for that {})".format(location, totalsteps))
print(dic1)
print(sum(dic1.values()))
# Out:
# The location of my person is 2, and total steps for that 2)
# The location of my person is 3, and total steps for that 3)
# The location of my person is 2, and total steps for that 4)
# The location of my person is 1, and total steps for that 5)
# The location of my person is 2, and total steps for that 6)
# The location of my person is 1, and total steps for that 7)
# The location of my person is 2, and total steps for that 8)
# The location of my person is 3, and total steps for that 9)
# The location of my person is 4, and total steps for that 10)
# The location of my person is 3, and total steps for that 11)
# The location of my person is 4, and total steps for that 12)
# The location of my person is 5, and total steps for that 13)
# The location of my person is 6, and total steps for that 14)
# The location of my person is 7, and total steps for that 15)
# The location of my person is 8, and total steps for that 16)
# The location of my person is 7, and total steps for that 17)
# The location of my person is 6, and total steps for that 18)
# The location of my person is 7, and total steps for that 19)
# The location of my person is 6, and total steps for that 20)
# The location of my person is 5, and total steps for that 21)
# The location of my person is 4, and total steps for that 22)
# The location of my person is 3, and total steps for that 23)
# The location of my person is 4, and total steps for that 24)
# The location of my person is 5, and total steps for that 25)
# The location of my person is 6, and total steps for that 26)
# The location of my person is 7, and total steps for that 27)
# The location of my person is 8, and total steps for that 28)
# The location of my person is 9, and total steps for that 29)
# The location of my person is 8, and total steps for that 30)
# The location of my person is 7, and total steps for that 31)
# The location of my person is 6, and total steps for that 32)
# The location of my person is 5, and total steps for that 33)
# The location of my person is 6, and total steps for that 34)
# The location of my person is 7, and total steps for that 35)
# The location of my person is 8, and total steps for that 36)
# The location of my person is 7, and total steps for that 37)
# The location of my person is 8, and total steps for that 38)
# The location of my person is 9, and total steps for that 39)
# The location of my person is 10, and total steps for that 40)
# {2: 4, 3: 4, 1: 2, 4: 4, 5: 4, 6: 6, 7: 7, 8: 5, 9: 2, 10: 1}
# 39

# %% [markdown]
# 6.
# Plot the graph
# Upon completion of the walk, we can display the contents of the array to show the relative
# progress of the walk. Consider other ways by which we might visualize information about the path:

# %%
import matplotlib.pyplot as plt
import random
import numpy as np

destination = 10
location = 1
totalsteps = 1
dic1 = dict()
while location < destination:
    move = random.uniform(1, 100)
    totalsteps += 1
    if move < 52:
        location += 1
    else:
        location -= 1
    if location not in dic1:
        dic1[location] = 1
    else:
        dic1[location] += 1
#plt.step(totalsteps, location)
#plt.show()
n, bins, patches = plt.hist(x=dic1.values(), bins=10 , color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Location')
plt.ylabel('Frequency')
plt.title('Histogram of steps')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 10.0)

# %%
import matplotlib.pyplot as plt
import random
import numpy as np

destination = 10
location = 1
totalsteps = 1
dic1 = dict()
dic2 = dict()
while location < destination:
    move = random.uniform(1, 100)
    #random seed  = надо посмотреть чтобы сделать reproducibility
    if move < 52:
        location += 1
    else:
        location -= 1
    if location not in dic1:
        dic1[location] = 1
    else:
        dic1[location] += 1
    dic2[totalsteps] = location
    totalsteps += 1
dic2
x= list(dic2.keys())
y = list(dic2.values())
plt.plot(x, y)
plt.show()

# %% [markdown]
# Set values for the starting point and ending point
# Initialize the value of “totalsteps” to 1
# Set Boolean “finished” to false
# While not “finished”
# Generate a random move (one value for x dimension, one for y)
# Increment “totalsteps”
# Adjust location (how to keep inside the “room”?
# Show updated location (during execution? Or at completion?)
# If location = ending point
#  then set “finished” to true
# The move could be generated in a manner similar to the earlier example, by separately generating a
# random value for the X and Y coordinates of the location (maybe, “LocationX” and “LocationY”), thus
# providing for vertical, horizontal, and diagonal movements.
#
#
# Another variation of the problem is that the simulation runs until it has touched every location in the
# room. In this case, how can you test for the exit condition?
#
#
# Finally, revise the program so that it runs in three dimensions … in this instance, how can you show
# the final results?

# %%
import numpy as np
mat = np.zeros((11, 11))
starting_point = (0,0)
ending_point = (10,10)
totalsteps = 0
LocationX = 1
LocationY = 1
finished = False
while not finished:
    x_rand = random.uniform(1, 100)
    y_rand = random.uniform(1, 100)
    totalsteps += 1
    if x_rand < 52:
        if LocationX < 10:
            LocationX += 1
    else:
        if LocationX > 0:
            LocationX -= 1
    if y_rand < 52:
        if LocationY < 10:
            LocationY += 1
    else:
        if LocationY > 0:
            LocationY -= 1
    location = (LocationX, LocationY) 
    if location == (10,10):
        finished = True
    mat[LocationX, LocationY] += 1
print(mat)
# Out:
# [[1. 2. 0. 0. 0. 0. 0. 0. 0. 0. 0.]
#  [5. 0. 2. 0. 0. 2. 0. 0. 0. 0. 0.]
#  [2. 5. 2. 2. 2. 0. 3. 0. 0. 0. 0.]
#  [6. 3. 1. 4. 2. 3. 0. 1. 0. 0. 0.]
#  [4. 4. 4. 1. 3. 1. 1. 0. 0. 0. 0.]
#  [3. 2. 3. 3. 0. 2. 0. 0. 0. 1. 2.]
#  [4. 3. 4. 1. 2. 0. 1. 0. 0. 2. 2.]
#  [3. 3. 1. 2. 0. 1. 1. 0. 3. 0. 2.]
#  [0. 1. 1. 1. 1. 1. 0. 2. 0. 8. 0.]
#  [1. 1. 3. 1. 1. 4. 2. 0. 5. 0. 1.]
#  [1. 1. 2. 3. 4. 4. 3. 2. 1. 1. 1.]]

# %%
# every tile once
import numpy as np
mat = np.zeros((11, 11))
starting_point = (0,0)
ending_point = (10,10)
totalsteps = 0
LocationX = 1
LocationY = 1
finished = False
while not finished:
    x_rand = random.uniform(1, 100)
    y_rand = random.uniform(1, 100)
    totalsteps += 1
    if x_rand < 52:
        if LocationX < 10:
            LocationX += 1
    else:
        if LocationX > 0:
            LocationX -= 1
    if y_rand < 52:
        if LocationY < 10:
            LocationY += 1
    else:
        if LocationY > 0:
            LocationY -= 1
    location = (LocationX, LocationY) 
    if 0 not in mat:
        finished = True
    mat[LocationX, LocationY] += 1
print(mat)
# Out:
# [[ 9.  7. 10.  9.  9.  6.  6. 11. 13.  5.  5.]
#  [ 5. 13.  4.  8.  8.  6. 16. 11. 11. 11.  1.]
#  [15.  5.  8. 10.  3. 13.  6. 13. 12.  8. 10.]
#  [ 7. 12.  8.  3. 12. 13.  6. 11.  6. 17. 12.]
#  [ 8.  7. 10.  7. 15.  9. 18.  7. 20.  5. 22.]
#  [ 7. 14.  7. 16. 12. 22. 12. 20. 12. 22. 14.]
#  [13.  7. 14. 15. 16. 15. 14. 16. 19. 15. 17.]
#  [13. 12. 11. 10. 18. 14. 23. 10. 24. 13. 17.]
#  [14. 10. 18. 17. 11. 24. 18. 30. 11. 29. 15.]
#  [ 7. 17. 14. 23. 25. 16. 23. 20. 33. 23. 28.]
#  [11. 11. 12. 18. 25. 17. 19. 29. 29. 33. 29.]]

# %%
# 3D
import numpy as np
mat = np.zeros((11, 11, 11))
starting_point = (0,0,0)
ending_point = (10,10,10)
totalsteps = 0
LocationX = 1
LocationY = 1
LocationZ = 1
finished = False
bias = 52
while not finished:
    x_rand = random.uniform(1, 100)
    y_rand = random.uniform(1, 100)
    z_rand = random.uniform(1, 100)
    totalsteps += 1
    if x_rand < bias:
        if LocationX < ending_point[0]:
            LocationX += 1
    else:
        if LocationX > 0:
            LocationX -= 1
    if y_rand < bias:
        if LocationY < ending_point[1]:
            LocationY += 1
    else:
        if LocationY > 0:
            LocationY -= 1
            
    if z_rand < bias:
        if LocationZ < ending_point[2]:
            LocationZ += 1
    else:
        if LocationZ > 0:
            LocationZ -= 1
    location = (LocationX, LocationY, LocationZ) 
#     if location == ending_point:
#         finished = True
    # every tile condition
    if 0 not in mat:
        finished = True
    mat[LocationX, LocationY, LocationZ] += 1

slice_num = 0
for x_slice in mat:
    print(slice_num, x_slice)
    slice_num += 1
# Out:
# 0 [[ 4.  5.  8.  4.  9.  5.  6.  2.  7.  7.  5.]
#  [ 3.  7.  6.  7.  2.  1.  4.  5.  5.  4.  5.]
#  [ 4.  9.  4.  7.  3.  5.  9.  5.  6.  6.  9.]
#  [ 6.  5.  4.  7.  8.  5.  5.  5.  5.  6. 11.]
#  [ 2.  7.  9.  9.  9. 10.  3.  7.  5. 13.  7.]
#  [16. 11.  7.  7.  9.  5.  5.  2. 12.  7. 10.]
#  [10.  8.  7. 10. 11.  8.  7.  9.  3. 11. 11.]
